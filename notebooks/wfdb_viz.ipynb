# %%
import wfdb
import matplotlib.pyplot as plt

# Load the ECG data from .hea and .dat files
record = wfdb.rdrecord('../../code15_wfdb/547')

# Display general information about the record
# print(record.__dict__)  # Optional: Shows metadata like sampling rate, duration, etc.

# Plotting the signals
wfdb.plot_wfdb(record=record, title='ECG Signal', time_units='seconds')
plt.show()
